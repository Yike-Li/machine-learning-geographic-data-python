# %%
# !pip install fiona
# !pip install geopandas

# %%
import fiona
import geopandas as gpd

fiona.drvsupport.supported_drivers['LIBKML'] = 'rw' # enable KML support which is disabled by default

kmlfile = gpd.read_file("sample_data/Untitled layer.kml")
print(kmlfile)
# Out:
#         Name description timestamp begin end altitudeMode  tessellate  \
# 0  Polygon 2        None       NaT   NaT NaT         None          -1
#
#    extrude  visibility drawOrder  icon  \
# 0        0          -1      None  None
#
#                                             geometry
# 0  POLYGON Z ((-122.50548 37.71229 0.00000, -122....

# %%
print(kmlfile.loc[0,'geometry'])
# Out:
# POLYGON Z ((-122.5054818 37.7122859 0, -122.3636889 37.7120142 0, -122.3794814 37.8129821 0, -122.5181853 37.8099983 0, -122.5054818 37.7122859 0))

# %%
import matplotlib.pyplot as plt
kmlfile.plot()
plt.title('Map in WGS 84')
# Out:
# Text(0.5, 1.0, 'Map in WGS 84')

# %%
kmlfile.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
proj_kml = kmlfile.to_crs('ESRI:102014')
proj_kml
# Out:
#         Name description timestamp begin end altitudeMode  tessellate  \
# 0  Polygon 2        None       NaT   NaT NaT         None          -1
#
#    extrude  visibility drawOrder  icon  \
# 0        0          -1      None  None
#
#                                             geometry
# 0  POLYGON Z ((-6215146.154 9078381.609 0.000, -6...

# %%
proj_kml.plot()
plt.title('ESRI:102014 map')
# Out:
# Text(0.5, 1.0, 'ESRI:102014 map')
