# %%
import geopandas as gpd
shapefile = gpd.read_file("sample_data/Communes_MGP.shp")
print(shapefile)
# Out:
#      ID_APUR   N_SQ_CAB  C_INSEE                L_CAB B_BOIS  \
# 0       1295  950001524    95018           Argenteuil    Non
# 1       1296  930000067    93039     LIle-Saint-Denis    Non
# 2       1297  930000063    93031     Epinay-sur-Seine    Non
# 3        543  930000064    93030                Dugny    Non
# 4        544  910001501    91479  Paray-Vieille-Poste    Non
# ..       ...        ...      ...                  ...    ...
# 147      885  750000018    75118                18ème    Non
# 148      886  750000019    75119                19ème    Non
# 149      887  750000020    75120                20ème    Non
# 150      888  750001534    75116                16ème    Oui
# 151      889  750001536    75112                12ème    Oui
#
#                 L_BOIS    N_SQ_AR    N_SQ_CO  \
# 0                 None       None  950001524
# 1                 None       None  930000067
# 2                 None       None  930000063
# 3                 None       None  930000064
# ...

# %%
shapefile.plot()
# Out:
# <AxesSubplot:>

# %%
import fiona
# fiona.drvsupport.supported_drivers['libkml'] = 'rw' # enable KML support which is disabled by default
fiona.drvsupport.supported_drivers['LIBKML'] = 'rw' # enable KML support which is disabled by default

import geopandas as gpd
kmlfile = gpd.read_file("sample_data/Communes_MGP.kml")
print(kmlfile)
# Out:
#      Name description timestamp begin end altitudeMode  tessellate  extrude  \
# 0    None        None       NaT   NaT NaT         None          -1        0
# 1    None        None       NaT   NaT NaT         None          -1        0
# 2    None        None       NaT   NaT NaT         None          -1        0
# 3    None        None       NaT   NaT NaT         None          -1        0
# 4    None        None       NaT   NaT NaT         None          -1        0
# ..    ...         ...       ...   ...  ..          ...         ...      ...
# 147  None        None       NaT   NaT NaT         None          -1        0
# 148  None        None       NaT   NaT NaT         None          -1        0
# 149  None        None       NaT   NaT NaT         None          -1        0
# 150  None        None       NaT   NaT NaT         None          -1        0
# 151  None        None       NaT   NaT NaT         None          -1        0
#
# ...

# %%
kmlfile.plot()
# Out:
# <AxesSubplot:>

# %%
import geopandas as gpd
geojsonfile = gpd.read_file("sample_data/Communes_MGP.json")
print(geojsonfile)
# Out:
#      ID_APUR   N_SQ_CAB  C_INSEE                L_CAB B_BOIS  \
# 0       1295  950001524    95018           Argenteuil    Non
# 1       1296  930000067    93039     LIle-Saint-Denis    Non
# 2       1297  930000063    93031     Epinay-sur-Seine    Non
# 3        543  930000064    93030                Dugny    Non
# 4        544  910001501    91479  Paray-Vieille-Poste    Non
# ..       ...        ...      ...                  ...    ...
# 147      885  750000018    75118                18ème    Non
# 148      886  750000019    75119                19ème    Non
# 149      887  750000020    75120                20ème    Non
# 150      888  750001534    75116                16ème    Oui
# 151      889  750001536    75112                12ème    Oui
#
#                 L_BOIS    N_SQ_AR    N_SQ_CO  \
# 0                 None       None  950001524
# 1                 None       None  930000067
# 2                 None       None  930000063
# 3                 None       None  930000064
# ...

# %%
geojsonfile.plot()
# Out:
# <AxesSubplot:>

# %%
import rasterio
from rasterio.plot import show
fp = r'sample_data\ore-kbz-mnt-litto3d-5m.tif'
img = rasterio.open(fp)
show(img)
# Out:
# <AxesSubplot:>
